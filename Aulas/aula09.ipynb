# %%
# %pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in c:\users\24114290157\appdata\roaming\python\python313\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\program files\python313\lib\site-packages (from pandas) (2.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\24114290157\appdata\roaming\python\python313\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\24114290157\appdata\roaming\python\python313\site-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\24114290157\appdata\roaming\python\python313\site-packages (from pandas) (2025.1)
# Requirement already satisfied: six>=1.5 in c:\users\24114290157\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
import numpy as np

# %%
seeds_df = pd.read_csv("../arquivosCsv/seeds.csv", header=None)
seeds_df.head(5)
# Out:
#        0      1       2      3      4      5      6  7
# 0  15.26  14.84  0.8710  5.763  3.312  2.221  5.220  1
# 1  14.88  14.57  0.8811  5.554  3.333  1.018  4.956  1
# 2  14.29  14.09  0.9050  5.291  3.337  2.699  4.825  1
# 3  13.84  13.94  0.8955  5.324  3.379  2.259  4.805  1
# 4  16.14  14.99  0.9034  5.658  3.562  1.355  5.175  1

# %%
seeds_df.to_numpy()
# Out:
# array([[15.26  , 14.84  ,  0.871 , ...,  2.221 ,  5.22  ,  1.    ],
#        [14.88  , 14.57  ,  0.8811, ...,  1.018 ,  4.956 ,  1.    ],
#        [14.29  , 14.09  ,  0.905 , ...,  2.699 ,  4.825 ,  1.    ],
#        ...,
#        [13.2   , 13.66  ,  0.8883, ...,  8.315 ,  5.056 ,  3.    ],
#        [11.84  , 13.21  ,  0.8521, ...,  3.598 ,  5.044 ,  3.    ],
#        [12.3   , 13.34  ,  0.8684, ...,  5.637 ,  5.063 ,  3.    ]],
#       shape=(210, 8))

# %%
from sklearn.decomposition import PCA

# %%
X = seeds_df.to_numpy()
pca = PCA(n_components=2)
components = pca.fit_transform(X)
# Out:
# array([ 0.76592401, -1.63823958])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test = train_test_split(components, test_size=0.3,
                                                    random_state=42)
X_train
# Out:
# array([[ 6.15159099, -0.71964467],
#        [ 2.60604265, -0.38844345],
#        [-3.12064491, -0.24343336],
#        [-3.40937739, -0.30009201],
#        [ 0.85538636, -0.49264326],
#        [-1.11206315, -0.28184644],
#        [ 1.61945387, -1.45346356],
#        [-0.63769059, -1.3580061 ],
#        [-1.76783505, -1.83284034],
#        [ 4.88981227, -0.58937445],
#        [ 3.92399934, -0.14670378],
#        [-3.23828293,  1.51648652],
#        [ 0.79238405,  1.56108236],
#        [ 4.42460758,  0.64385299],
#        [-4.61268303,  2.51937423],
#        [ 2.82606785,  0.5850392 ],
#        [-1.25025623, -1.92181877],
#        [-3.19881742,  4.34237664],
#        [ 4.4442544 ,  2.04004126],
#        [ 1.15205688, -0.2059844 ],
#        [-1.91153285, -0.97403874],
#        [-2.17605659,  1.53694045],
#        [-4.10630174,  1.76057749],
#        [ 1.47638091,  0.80199848],
#        [-0.55342906, -1.42163614],
#        [ 6.42164839,  1.75724769],
#        [ 0.9263447 , -2.43670711],
#        [ 3.61252093, -0.79753343],
#        [ 4.87513634, -0.75017154],
#        [ 6.1206368 , -0.66052604],
#        [ 3.99317027, -0.53794812],
#        [-2.15598318,  3.18859278],
#        [ 1.7453318 , -0.89766226],
#        [ 5.85619401,  0.34093655],
#        [-3.87751551, -2.3353998 ],
#        [ 1.51597435, -2.92849787],
#        [ 1.08116446, -0.73512608],
#        [ 5.05492338,  0.77850943],
#        [-0.71266382, -1.96782593],
#        [-0.5975957 , -2.34232666],
#        [-2.87183024,  0.08087832],
#        [-2.97937687, -0.1705866 ],
#        [-0.08668926, -0.47070657],
#        [-2.07942038, -1.82071968],
#        [-4.13492087,  2.5495108 ],
#        [-2.491905  , -1.43092405],
#        [-3.44065561,  0.54096473],
#        [ 1.7232104 , -2.33066628],
#        [-0.6688501 , -0.22789788],
#        [ 4.39926156,  3.54439759],
#        [-2.97169868,  0.89641337],
#        [ 5.6382666 ,  2.9920377 ],
#        [-3.20040496,  0.23486224],
#        [ 6.62848952,  1.98897559],
#        [ 0.45790153,  0.5314948 ],
#        [-2.76250017, -1.27138579],
#        [-2.34147629, -0.43827386],
#        [-4.03690449, -0.64554359],
#        [-4.23650225,  1.23498273],
#        [ 0.76592401, -1.63823958],
#        [-5.07950127,  0.73549295],
#        [-2.51446149,  2.31764349],
#        [ 3.14389557,  0.88172992],
#        [-2.70134081,  0.59731005],
#        [-1.92653028, -3.07197977],
#        [ 0.383163  , -0.84331509],
#        [ 1.10309879, -0.80023494],
#        [-1.26052322, -1.6019809 ],
#        [ 3.96617532, -0.05664272],
#        [-2.71585335, -2.95026167],
#        [-3.42032247,  0.47076465],
#        [-3.93574269,  0.06794812],
#        [ 4.00495327,  2.17270042],
#        [-1.03120789,  2.31454469],
#        [-4.74865237,  0.54678852],
#        [ 0.29692297, -1.01639155],
#        [ 3.98532013,  1.86270733],
#        [-3.24070412,  0.38880354],
#        [ 0.71560834,  0.74548993],
#        [-4.31211649,  2.0342116 ],
#        [-0.94321347, -1.89897174],
#        [ 4.50689886, -0.38579824],
#        [-0.46499302, -0.77264508],
#        [ 1.47378724,  0.79039402],
#        [-4.64078094,  1.22808029],
#        [-4.58748099,  2.17500469],
#        [-2.61908668,  1.01398819],
#        [ 0.35933529, -1.7768324 ],
#        [ 1.65688638,  2.02587386],
#        [ 0.54366582, -1.74992262],
#        [-0.67319621, -1.42153194],
#        [ 4.14451374, -0.74713954],
#        [ 4.37474528,  0.14850691],
#        [ 5.57170396, -1.21816163],
#        [-3.45882723,  0.96065369],
#        [-4.11969818, -0.04294772],
#        [ 6.41628474,  2.27599063],
#        [ 2.37629964, -1.51804185],
#        [-1.06233792, -1.0703638 ],
#        [-2.64470742, -2.88836201],
#        [-2.92978356,  1.09768928],
#        [ 4.59494784, -0.02870422],
#        [ 1.16206693, -2.19386082],
#        [-2.85537508,  1.06327014],
#        [ 2.60070699,  1.2158457 ],
#        [-3.65382768,  0.12301686],
#        [ 0.67814906,  1.34424069],
#        [-4.75654603,  0.61351517],
#        [-4.64000832,  0.71757218],
#        [-1.77049087, -0.1882054 ],
#        [ 0.12844691, -2.41314225],
#        [ 3.10520228,  0.54900462],
#        [-0.4079817 , -0.15375839],
#        [-4.59815738,  1.04684922],
#        [-4.18690581,  0.27191016],
#        [-4.02813863, -0.46112096],
#        [ 0.87285818, -1.83779502],
#        [ 0.11830604, -1.28809659],
#        [ 6.64545727,  3.03212395],
#        [-0.58302553, -1.39765455],
#        [ 0.39573957, -2.73998717],
#        [-2.4472239 , -0.60807778],
#        [-4.29443863, -0.02187463],
#        [ 2.6882461 ,  1.99880859],
#        [ 2.56456441, -0.65856475],
#        [-3.07357075,  0.93923553],
#        [-2.44144889, -0.4154898 ],
#        [ 0.42823704, -2.85745423],
#        [-0.26055506,  0.02773461],
#        [-4.67560417,  1.30273072],
#        [ 3.84535154, -0.21010837],
#        [-3.53962118,  2.93258986],
#        [ 4.91624625,  0.47528822],
#        [ 4.51809516, -0.70913625],
#        [ 4.3459326 ,  1.27129588],
#        [ 4.76342313,  0.79514181],
#        [ 2.19797679,  0.65285327],
#        [ 3.68570792,  0.52074291],
#        [-3.19933421,  1.67007829],
#        [-0.52748368, -1.02335052],
#        [-4.64686016,  3.24033037],
#        [ 2.19078017,  1.29396737],
#        [ 4.49634337, -0.08688852],
#        [-1.08447338, -1.27052737],
#        [ 4.43981556,  0.27325471],
#        [-2.67667444, -2.01967059],
#        [ 4.94736363,  1.35763645]])

# %%
from sklearn.cluster import KMeans

# %%
model = KMeans(n_clusters=3)

# %%
model.fit(X_train)
# Out:
# KMeans(n_clusters=3)

# %%
labels = model.predict(X_train)

# %%
new_labels = model.predict(X_test)

# %%
print(new_labels)
# Out:
# [2 0 1 0 0 0 2 0 2 0 1 0 0 1 2 1 0 2 0 1 1 2 0 1 1 0 2 1 0 0 0 2 1 2 1 2 0
#  1 1 0 0 0 0 1 0 2 0 1 2 2 2 0 1 2 0 2 2 2 2 2 0 2 1]

# %%
import matplotlib.pyplot as plt

# %%
x = X_train[:, 0]  # sepal length
y = X_train[:, 1]  # petal length

# %%
plt.scatter(x, y, c=labels)
plt.show()
